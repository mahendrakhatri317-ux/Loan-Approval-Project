# %% [markdown]
# #  Loan_Approval_project

# %%
import os 
import numpy as np 
import pandas as pd 
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Jaishree\OneDrive\Desktop\DATA SCIENCE\Project\loan_approval.csv") 
df
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
df
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
df.head()
# Out:
#               name              city  income  credit_score  loan_amount  \
# 0     Allison Hill         East Jill  113810           389        39698
# 1     Brandon Hall     New Jamesside   44592           729        15446
# 2     Rhonda Smith      Lake Roberto   33278           584        11189
# 3  Gabrielle Davis  West Melanieview  127196           344        48823
# 4     Valerie Gray         Mariastad   66048           496        47174
#
#    years_employed  points  loan_approved
# 0              27    50.0          False
# 1              28    55.0          False
# 2              13    45.0          False
# 3              29    50.0          False
# 4               4    25.0          False

# %%
df.head(10)
# Out:
#               name              city  income  credit_score  loan_amount  \
# 0     Allison Hill         East Jill  113810           389        39698
# 1     Brandon Hall     New Jamesside   44592           729        15446
# 2     Rhonda Smith      Lake Roberto   33278           584        11189
# 3  Gabrielle Davis  West Melanieview  127196           344        48823
# 4     Valerie Gray         Mariastad   66048           496        47174
# 5   Darren Roberts   Port Jesseville   62098           689        19217
# 6       Holly Wood       Lake Joseph   59256           373        40920
# 7  Nicholas Martin        Nelsonside   48289           524        45866
# 8      Patty Perez   Port Leslieview  126530           367        14826
# 9       Emily Rios    Wilkersonmouth   43434           446        18359
#
#    years_employed  points  loan_approved
# 0              27    50.0          False
# 1              28    55.0          False
# 2              13    45.0          False
# ...

# %%
df.tail()
# Out:
#                 name            city  income  credit_score  loan_amount  \
# 1995  James Schaefer       Robertton   92163           770        12251
# 1996       Diana Lin       New Frank   38799           635        48259
# 1997   Brandon Meyer      East Haley   41957           763        16752
# 1998     Jason Price        Adamland  139022           360        24031
# 1999    Nicole Brown  New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# 1995              13    85.0           True
# 1996              17    40.0          False
# 1997               5    60.0           True
# 1998              35    55.0          False
# 1999               6    20.0          False

# %%
df.tail(15)
# Out:
#                       name              city  income  credit_score  \
# 1985           Kevin White      Anthonyshire  125631           765
# 1986       Cynthia Johnson     East Ryanstad   42463           765
# 1987          Sandra Lopez  West Tiffanyside   70966           305
# 1988         Teresa Bowers      Matthewmouth   85936           420
# 1989       Michael Lambert     South Kenneth   70963           489
# 1990        Rebecca Newman  West Christopher  117177           712
# 1991  Christopher Morrison         Cookshire   63408           376
# 1992         Sierra Gentry      Jenniferstad   79060           572
# 1993         Hannah Carter           Basston   50006           626
# 1994           Ryan Thomas         Tylertown  120023           318
# 1995        James Schaefer         Robertton   92163           770
# 1996             Diana Lin         New Frank   38799           635
# 1997         Brandon Meyer        East Haley   41957           763
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2000 non-null   str
#  1   city            2000 non-null   str
#  2   income          2000 non-null   int64
#  3   credit_score    2000 non-null   int64
#  4   loan_amount     2000 non-null   int64
#  5   years_employed  2000 non-null   int64
#  6   points          2000 non-null   float64
#  7   loan_approved   2000 non-null   bool
# dtypes: bool(1), float64(1), int64(4), str(2)
# memory usage: 111.5 KB

# %%
df.columns
# Out:
# Index(['name', 'city', 'income', 'credit_score', 'loan_amount',
#        'years_employed', 'points', 'loan_approved'],
#       dtype='str')

# %%
df[['name']]
# Out:
#                  name
# 0        Allison Hill
# 1        Brandon Hall
# 2        Rhonda Smith
# 3     Gabrielle Davis
# 4        Valerie Gray
# ...               ...
# 1995   James Schaefer
# 1996        Diana Lin
# 1997    Brandon Meyer
# 1998      Jason Price
# 1999     Nicole Brown
#
# [2000 rows x 1 columns]

# %%
df[['city']]
# Out:
#                   city
# 0            East Jill
# 1        New Jamesside
# 2         Lake Roberto
# 3     West Melanieview
# 4            Mariastad
# ...                ...
# 1995         Robertton
# 1996         New Frank
# 1997        East Haley
# 1998          Adamland
# 1999    New Nathantown
#
# [2000 rows x 1 columns]

# %%
df[['income']]
# Out:
#       income
# 0     113810
# 1      44592
# 2      33278
# 3     127196
# 4      66048
# ...      ...
# 1995   92163
# 1996   38799
# 1997   41957
# 1998  139022
# 1999   41188
#
# [2000 rows x 1 columns]

# %%
df[['credit_score']]
# Out:
#       credit_score
# 0              389
# 1              729
# 2              584
# 3              344
# 4              496
# ...            ...
# 1995           770
# 1996           635
# 1997           763
# 1998           360
# 1999           482
#
# [2000 rows x 1 columns]

# %%
df[['loan_amount']]
# Out:
#       loan_amount
# 0           39698
# 1           15446
# 2           11189
# 3           48823
# 4           47174
# ...           ...
# 1995        12251
# 1996        48259
# 1997        16752
# 1998        24031
# 1999        31397
#
# [2000 rows x 1 columns]

# %%
df[['years_employed']]
# Out:
#       years_employed
# 0                 27
# 1                 28
# 2                 13
# 3                 29
# 4                  4
# ...              ...
# 1995              13
# 1996              17
# 1997               5
# 1998              35
# 1999               6
#
# [2000 rows x 1 columns]

# %%
df[['points']]
# Out:
#       points
# 0       50.0
# 1       55.0
# 2       45.0
# 3       50.0
# 4       25.0
# ...      ...
# 1995    85.0
# 1996    40.0
# 1997    60.0
# 1998    55.0
# 1999    20.0
#
# [2000 rows x 1 columns]

# %%
df[['loan_approved']]
# Out:
#       loan_approved
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1995           True
# 1996          False
# 1997           True
# 1998          False
# 1999          False
#
# [2000 rows x 1 columns]

# %%
df[['city' , 'income']]
# Out:
#                   city  income
# 0            East Jill  113810
# 1        New Jamesside   44592
# 2         Lake Roberto   33278
# 3     West Melanieview  127196
# 4            Mariastad   66048
# ...                ...     ...
# 1995         Robertton   92163
# 1996         New Frank   38799
# 1997        East Haley   41957
# 1998          Adamland  139022
# 1999    New Nathantown   41188
#
# [2000 rows x 2 columns]

# %%
df[['loan_amount' , 'points' , 'loan_approved']]
# Out:
#       loan_amount  points  loan_approved
# 0           39698    50.0          False
# 1           15446    55.0          False
# 2           11189    45.0          False
# 3           48823    50.0          False
# 4           47174    25.0          False
# ...           ...     ...            ...
# 1995        12251    85.0           True
# 1996        48259    40.0          False
# 1997        16752    60.0           True
# 1998        24031    55.0          False
# 1999        31397    20.0          False
#
# [2000 rows x 3 columns]

# %%
df[['credit_score', 'years_employed', 'loan_approved', 'income']]
# Out:
#       credit_score  years_employed  loan_approved  income
# 0              389              27          False  113810
# 1              729              28          False   44592
# 2              584              13          False   33278
# 3              344              29          False  127196
# 4              496               4          False   66048
# ...            ...             ...            ...     ...
# 1995           770              13           True   92163
# 1996           635              17          False   38799
# 1997           763               5           True   41957
# 1998           360              35          False  139022
# 1999           482               6          False   41188
#
# [2000 rows x 4 columns]

# %%
df['loan_approved'].unique()
# Out:
# array([False,  True])

# %%
df['credit_score'].unique()
# Out:
# array([389, 729, 584, 344, 496, 689, 373, 524, 367, 446, 670, 365, 573,
#        819, 843, 380, 469, 682, 525, 543, 716, 400, 443, 792, 592, 362,
#        382, 383, 434, 402, 748, 406, 651, 345, 309, 451, 405, 481, 658,
#        659, 482, 418, 638, 712, 608, 518, 395, 374, 775, 624, 760, 750,
#        456, 698, 385, 634, 353, 471, 326, 548, 370, 574, 688, 310, 802,
#        784, 613, 795, 669, 789, 611, 761, 512, 781, 570, 572, 630, 341,
#        393, 807, 713, 810, 424, 416, 725, 724, 692, 315, 646, 336, 667,
#        691, 461, 609, 322, 535, 340, 479, 793, 706, 690, 364, 333, 321,
#        521, 433, 787, 375, 601, 533, 683, 361, 594, 356, 307, 746, 596,
#        390, 526, 454, 772, 773, 813, 553, 641, 617, 458, 685, 720, 616,
#        814, 579, 657, 401, 780, 840, 768, 739, 838, 436, 486, 342, 756,
#        581, 457, 621, 420, 597, 505, 432, 346, 708, 399, 620, 520, 410,
#        499, 431, 821, 827, 726, 332, 632, 800, 654, 440, 391, 337, 605,
# ...

# %%
df['name'].unique()
# Out:
# <StringArray>
# [        'Allison Hill',         'Brandon Hall',         'Rhonda Smith',
#       'Gabrielle Davis',         'Valerie Gray',       'Darren Roberts',
#            'Holly Wood',      'Nicholas Martin',          'Patty Perez',
#            'Emily Rios',
#  ...
#        'Rebecca Newman', 'Christopher Morrison',        'Sierra Gentry',
#         'Hannah Carter',          'Ryan Thomas',       'James Schaefer',
#             'Diana Lin',        'Brandon Meyer',          'Jason Price',
#          'Nicole Brown']
# Length: 2000, dtype: str

# %%
df['city'].unique()
# Out:
# <StringArray>
# [       'East Jill',    'New Jamesside',     'Lake Roberto',
#  'West Melanieview',        'Mariastad',  'Port Jesseville',
#       'Lake Joseph',       'Nelsonside',  'Port Leslieview',
#    'Wilkersonmouth',
#  ...
#     'South Kenneth',        'Cookshire',     'Jenniferstad',
#           'Basston',        'Tylertown',        'Robertton',
#         'New Frank',       'East Haley',         'Adamland',
#    'New Nathantown']
# Length: 1882, dtype: str

# %%
df['income'].unique()
# Out:
# array([113810,  44592,  33278, ...,  41957, 139022,  41188], shape=(1988,))

# %%
df['loan_amount'].unique()
# Out:
# array([39698, 15446, 11189, ..., 16752, 24031, 31397], shape=(1968,))

# %%
df['years_employed'].unique()
# Out:
# array([27, 28, 13, 29,  4, 40, 20, 36,  8, 24, 21, 38, 31, 33,  6, 25, 11,
#        34, 35,  3, 37, 19, 16,  1, 14, 32, 18, 30, 26,  0, 39, 15, 12,  2,
#        22,  7,  9, 23, 17, 10,  5])

# %%
df['points'].unique()
# Out:
# array([ 50.,  55.,  45.,  25.,  65.,  35.,  20.,  75., 100.,  80.,  60.,
#         30.,  10.,  70.,  90.,  40.,  85.,  95.,  15.])

# %%
df['city'].value_counts()
# Out:
# city
# North Joseph        4
# North Michael       3
# Port Michael        3
# Christinachester    3
# West Melissa        3
#                    ..
# Robertton           1
# New Frank           1
# East Haley          1
# Adamland            1
# New Nathantown      1
# Name: count, Length: 1882, dtype: int64

# %%
df['name'].value_counts()
# Out:
# name
# Allison Hill       1
# Brandon Hall       1
# Rhonda Smith       1
# Gabrielle Davis    1
# Valerie Gray       1
#                   ..
# James Schaefer     1
# Diana Lin          1
# Brandon Meyer      1
# Jason Price        1
# Nicole Brown       1
# Name: count, Length: 2000, dtype: int64

# %%
df['loan_amount'].value_counts()
# Out:
# loan_amount
# 9800     2
# 46238    2
# 28119    2
# 24758    2
# 48578    2
#         ..
# 12251    1
# 48259    1
# 16752    1
# 24031    1
# 31397    1
# Name: count, Length: 1968, dtype: int64

# %%
df['credit_score'].value_counts()
# Out:
# credit_score
# 395    10
# 645    10
# 468    10
# 546    10
# 725     9
#        ..
# 348     1
# 822     1
# 788     1
# 623     1
# 757     1
# Name: count, Length: 537, dtype: int64

# %%
df['income'].value_counts()
# Out:
# income
# 104177    3
# 100010    2
# 102512    2
# 118039    2
# 59451     2
#          ..
# 92163     1
# 38799     1
# 41957     1
# 139022    1
# 41188     1
# Name: count, Length: 1988, dtype: int64

# %%
df['years_employed'].value_counts()
# Out:
# years_employed
# 23    67
# 38    62
# 9     61
# 17    59
# 21    57
# 25    57
# 34    56
# 10    56
# 6     55
# 13    54
# 24    54
# 37    53
# 36    52
# 19    52
# 20    51
# 39    51
# 28    50
# 29    50
# 40    50
# 31    50
# 30    50
# 7     50
# 8     48
# 3     47
# 11    46
# 35    46
# 32    46
# 26    45
# 22    45
# 4     44
# 0     43
# 1     42
# 15    42
# 2     42
# 27    41
# 12    41
# 14    39
# 5     39
# 33    36
# 16    36
# 18    35
# Name: count, dtype: int64

# %%
df['points'].value_counts()
# Out:
# points
# 50.0     271
# 55.0     210
# 60.0     193
# 45.0     170
# 40.0     164
# 65.0     130
# 35.0     127
# 75.0     119
# 70.0     111
# 80.0      97
# 25.0      95
# 85.0      94
# 90.0      77
# 30.0      59
# 95.0      38
# 100.0     20
# 20.0      18
# 10.0       4
# 15.0       3
# Name: count, dtype: int64

# %%
df['loan_approved'].value_counts()
# Out:
# loan_approved
# False    1121
# True      879
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
df.drop_duplicates().sum()
# Out:
# name              Allison HillBrandon HallRhonda SmithGabrielle ...
# city              East JillNew JamessideLake RobertoWest Melanie...
# income                                                    181171954
# credit_score                                                1147892
# loan_amount                                                50617006
# years_employed                                                40882
# points                                                     113360.0
# loan_approved                                                   879
# dtype: object

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
df.isnull()
# Out:
#        name   city  income  credit_score  loan_amount  years_employed  points  \
# 0     False  False   False         False        False           False   False
# 1     False  False   False         False        False           False   False
# 2     False  False   False         False        False           False   False
# 3     False  False   False         False        False           False   False
# 4     False  False   False         False        False           False   False
# ...     ...    ...     ...           ...          ...             ...     ...
# 1995  False  False   False         False        False           False   False
# 1996  False  False   False         False        False           False   False
# 1997  False  False   False         False        False           False   False
# 1998  False  False   False         False        False           False   False
# 1999  False  False   False         False        False           False   False
#
#       loan_approved
# ...

# %%
df.isnull().sum()
# Out:
# name              0
# city              0
# income            0
# credit_score      0
# loan_amount       0
# years_employed    0
# points            0
# loan_approved     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2000 non-null   str
#  1   city            2000 non-null   str
#  2   income          2000 non-null   int64
#  3   credit_score    2000 non-null   int64
#  4   loan_amount     2000 non-null   int64
#  5   years_employed  2000 non-null   int64
#  6   points          2000 non-null   float64
#  7   loan_approved   2000 non-null   bool
# dtypes: bool(1), float64(1), int64(4), str(2)
# memory usage: 111.5 KB

# %%
df.dropna(inplace=True)
df
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# ...

# %%
object_columns = df.select_dtypes(include=['object']).columns
object_columns
# Out:
# C:\Users\Jaishree\AppData\Local\Temp\ipykernel_13560\1051871239.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   object_columns = df.select_dtypes(include=['object']).columns
# Index(['name', 'city'], dtype='str')

# %%
num_values = df.select_dtypes(include=['number']).columns
num_values
# Out:
# Index(['income', 'credit_score', 'loan_amount', 'years_employed', 'points'], dtype='str')

# %%
complete_df = pd.concat([df[object_columns], df[num_values]], axis=1)
complete_df
# Out:
#                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points
# 0                 27    50.0
# ...

# %%
sns.lineplot(df['credit_score'])
plt.show()

# %%
sns.lineplot(df['loan_amount'])
plt.show()

# %%
sns.lineplot(df['years_employed'])
plt.show()

# %%
sns.lineplot(df['points'])
plt.show()

# %%
sns.scatterplot(x = 'loan_amount' , y='years_employed' , data=df)
plt.show()

# %%
sns.scatterplot(x = 'credit_score' , y='points' , data=df)
plt.show()

# %%
plt.hist(df['credit_score'])
plt.show()

# %%
plt.hist(df['points'])
plt.show()

# %%
sns.kdeplot(df['loan_amount'])
plt.show()

# %%
sns.kdeplot(df['years_employed'])
plt.show()

# %%
sns.relplot(x='loan_amount' , y='years_employed' , data=df)
plt.show()

# %%
sns.relplot(x='points' , y='credit_score' , data=df)
plt.show()

# %%
sns.catplot(x='points' , y='credit_score' , data=df)
plt.show()

# %%
# sns.relplot(x='years_employed' , y='credit_score', hue='points'  , col='income', data=df)
# plt.show()

# %%
# sns.relplot(x='years_employed' , y='credit_score', hue='city'  , col='income', data=df)
# plt.show()

# %%
sns.catplot(x = 'years_employed' , y = 'credit_score' , kind='bar' , data=df)
plt.show()

# %%
sns.catplot(x = 'years_employed' , y = 'credit_score' , kind='box' , data=df)
plt.show()

# %%
sns.catplot(x = 'years_employed' , y = 'credit_score' , kind='boxen' , data=df)
plt.show()

# %%
sns.catplot(x='years_employed', kind='count', data=df)
plt.show()

# %%
sns.catplot( y = 'credit_score' , kind='point' , data=df)
plt.show()

# %%
sns.catplot(x = 'years_employed'  , kind='strip' , data=df)
plt.show()

# %%
sns.catplot(y = 'credit_score' , kind='swarm' , data=df)
plt.show()

# %%
sns.catplot(x = 'years_employed'  , kind='violin' , data=df)
plt.show()

# %%
sns.countplot(x='credit_score', data=df)
plt.title('credit score Distribution')
plt.show()

# %%
sns.countplot(x='loan_amount', data=df)
plt.title('loan amount Distribution')
plt.show()

# %%
sns.countplot(x='years_employed', data=df)
plt.title('year employed Distribution')
plt.show()

# %%
sns.countplot(x='points', data=df)
plt.title('points Distribution')
plt.show()

# %%
sns.countplot(x='credit_score' , hue='loan_amount', data=df)
plt.title('credit score vs loan amount')
plt.show()

# %%
sns.countplot(x='years_employed' , hue='points', data=df)
plt.title('years_employed vs points')
plt.show()

# %%
sns.histplot([df['credit_score']], bins=30, kde=True)
plt.title('credit_score Distribution')
plt.show()

# %%
sns.histplot([df['years_employed']], bins=30, kde=True)
plt.title('years_employed Distribution')
plt.show()

# %%
sns.histplot([df['loan_amount']], bins=30, kde=True)
plt.title('loan_amount Distribution')
plt.show()

# %%
sns.histplot([df['points']], bins=30, kde=True)
plt.title('points Distribution')
plt.show()

# %%
sns.scatterplot(x='years_employed', y='points', data=df)
plt.show()

# %%
sns.scatterplot(x='credit_score', y='loan_amount', data=df)
plt.show()

# %%
sns.scatterplot(x='credit_score', y='loan_amount', data=df)
plt.show()

# %%
sns.boxplot(x='years_employed', hue='points', data=df)
plt.title('Class Distribution by Satisfaction')
plt.show()

# %%
sns.boxplot(x='credit_score' , hue='loan_amount', data=df)
plt.title('credit score vs loan amount')
plt.show()
# Out:
# c:\Users\Jaishree\OneDrive\Desktop\DATA SCIENCE\datascience\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', )
plt.title('Correlation Heatmap')
plt.show()
